# %%
import sys; sys.path.append('..')
import random

import albumentations as A
import cv2
import matplotlib.pyplot as plt
from PIL import Image

from model_jittor.dataset_jittor import *

PATH = '/nas/landscape/train_val/images/'

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
val_loader =

# %%
train_loader, val_loader = get_train_val_vq_dataloader()
# Out:
# There are total 10000 images,  use 9000 images for training and  1000 images for validation.
# save train and val image names in train.txt and val.txt

# %%
image, name = train_loader[0]
img_orig = Image.open(os.path.join(PATH, f"{name}.jpg"))
img = np.asarray(img_orig, dtype=np.float32) / 255.0

# %%
print(img.shape)
plt.imshow(img)
# Out:
# (768, 1024, 3)

# %%
print(image.shape, image.max(), image.min())
img_r = (image.numpy() + 1) / 2
print(img_r.shape, img_r.max(), img_r.min())
plt.imshow(img_r.transpose(1, 2, 0))
# Out:
# [3,256,256,] jt.Var([1.], dtype=float32) jt.Var([-0.9529412], dtype=float32)
# (3, 256, 256) 1.0 0.02352941
