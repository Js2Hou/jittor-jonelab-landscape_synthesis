# %%
import sys; sys.path.append('..')

import torch
import wandb
import numpy as np
from einops import rearrange
from PIL import Image
import utils

# %%
img = Image.open('/nas/landscape/train_val/images/4576778279_65e7a588a9_b.jpg')
img = np.array(img)
print(img.shape)
Image.fromarray(img)
# Out:
# (768, 1024, 3)
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
img_batch_channel_last = rearrange(img, '(nh h) (nw w) c -> (nh nw) h w c', nh=3, nw=2)
print(img_batch_channel_last.shape)
# Out:
# (6, 256, 512, 3)

# %%
for i in img_batch_channel_last:
    Image.fromarray(i).show()
# Out:
# <PIL.Image.Image image mode=RGB size=512x256>
# <PIL.Image.Image image mode=RGB size=512x256>
# <PIL.Image.Image image mode=RGB size=512x256>
# <PIL.Image.Image image mode=RGB size=512x256>
# <PIL.Image.Image image mode=RGB size=512x256>
# <PIL.Image.Image image mode=RGB size=512x256>

# %%
grid_1 = utils.make_grid(img_batch_channel_last, n_cols=2) 
print(grid_1.shape)
Image.fromarray(grid_1)
# Out:
# (768, 1024, 3)
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
img_batch_channel_first = rearrange(img_batch_channel_last, 'b h w c -> b c h w')
print(img_batch_channel_first.shape)
# Out:
# (6, 3, 256, 512)

# %%
grid_1 = utils.make_grid(img_batch_channel_last, n_cols=2) 
print(grid_1.shape)
Image.fromarray(grid_1)
# Out:
# (768, 1024, 3)
# <PIL.Image.Image image mode=RGB size=1024x768>
