# %%
import sys; sys.path.append('..')
import random

import albumentations as A
import cv2
import matplotlib.pyplot as plt
from PIL import Image

from dataset_torch import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
transform = A.Compose([
    A.RandomCrop(width=384, height=384),
    A.Resize(height=256, width=256),
    A.HorizontalFlip(p=0.5),
    # A.RandomBrightnessContrast(p=0.2),
])

# %%
dataset = VQDataset(
    image_root='../data/landscape/train_val/images', 
    file_list='../data/landscape/train.txt',
    transform=transform, 
    split='train',
)
# Out:
# train dataset size:  9000

# %%
idx = random.randint(0, len(dataset))
print(idx)
# Out:
# 8531

# %%
item = dataset[idx]
print(item[1])
plt.imshow(item[0])
# Out:
# 5222462266_429c1cba5e_b

# %%
Image.open(f"../data/landscape/train_val/images/{item[1]}.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768>
